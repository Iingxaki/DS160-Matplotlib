# %% [markdown]
# # Introduction to data visualization using MatplotLib

# %% [markdown]
# ## Data is only as good as it’s presented.
# ### Why are visualizations important?
# * Visualizations are the easiest way to analyze and absorb information.
# * Visuals help to easily understand the complex problem.
# * They help in identifying patterns, relationships, and outliers in data.
# * It helps in understanding business problems better and quickly.
# * It helps to build a compelling story based on visuals.
# * Insights gathered from the visuals help in building strategies for businesses.
# * It is also a precursor to many high-level data analysis for Exploratory Data Analysis(EDA) and Machine Learning(ML).

# %% [markdown]
# ## Matplotlib
# * Matplotlib is a 2-D plotting library that helps in visualizing figures.
# * Matplotlib emulates Matlab like graphs and visualizations.
# * Matlab is not free, is difficult to scale and as a programming language is tedious.
# * So, matplotlib in Python is used as it is a robust, free and easy library for data visualization.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Installing Matplotlib
# * `!pip install matplotlib` in the Jupyter Notebook or
# * cmd type conda install `-c conda-forge matplotlib`
# * `import matplotlib.pyplot as plt` for making it call the package module

# %% [markdown]
# ## Pandas Recall and Matplotlib basics
# * Importing required libraries using Pandas `pd.read_csv()`
# * Extracting important parts for plots using conditions on Pandas Dataframes.
# * `plt.plot()`for plotting line chart similarly in place of plot other functions are used for plotting.
# * `plt.xlabel` , `plt.ylabel` for labeling x and y-axis respectively.
# * `plt.xticks` , `plt.yticks` for labeling x and y-axis observation tick points respectively.
# * `plt.legend()` for signifying the observation variables.
# * `plt.title()` for setting the title of the plot.
# * `plt.show()` for displaying the plot.

# %% [markdown]
# ### Here you will learn:
# * 1.Histogram
# * 2.Piechart
# * 3.Line Chart
# * 4.Box plot
# * 5.Twin axis
# * 6.Stack plot
# * 7.Bar plot
# * 8.Scatter plot

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rhukom\.conda\envs\ds160\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## 1 Histogram : We should use histogram when we need the count of the variable in a plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_hist=pd.read_csv("national_parks.csv")
df_hist.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
plt.hist(df_hist['GrandCanyon'],facecolor='darkgreen',edgecolor='blue',bins=10)
plt.title('Histogram plot of Grand Canyon')
plt.ylabel('Frequency')
plt.xlabel('Bins')
plt.show()

# %% [markdown]
# ### Components of a histogram
# * <b>n:</b> Contains the frequency of each bin
# * <b>bins:</b> Represents the middle value of each bin
# * <b>patches:</b> The Patch object for the rectangle shape representing each bar

# %%
plt.hist(df_hist['GrandCanyon'],facecolor='darkgreen',edgecolor='blue',bins=10)
plt.title('Histogram plot of Grand Canyon')
plt.ylabel('Frequency')
plt.xlabel('Bins')
plt.show()

# %% [markdown]
# #### The cumulative property
# If True, then a histogram is computed where each bin gives the counts in that bin plus all bins for smaller values. The last bin gives the total number of datapoints.

# %%
df_hist.columns
# Out:
# Index(['Year', 'Badlands', 'GrandCanyon', 'BryceCanyon'], dtype='object')

# %%
plt.hist(df_hist['BryceCanyon'],facecolor='indigo',edgecolor='blue',bins=10,cumulative=True)
plt.title('Histogram plot of Bryce Canyon')
plt.ylabel('Frequency')
plt.xlabel('Bins')
plt.show()

# %% [markdown]
# #### Check the histogram to a range of values
# We only look at the data points within the range 2M-5M. This realigns the bins in the histogram

# %%
df_hist.describe()
# Out:
#               Year      Badlands   GrandCanyon   BryceCanyon
# count    57.000000  5.700000e+01  5.700000e+01  5.700000e+01
# mean   1989.000000  1.069524e+06  3.412695e+06  8.408708e+05
# std      16.598193  1.574500e+05  1.255127e+06  4.816281e+05
# min    1961.000000  8.333000e+05  1.253000e+06  2.510000e+05
# 25%    1975.000000  9.502420e+05  2.258200e+06  4.715170e+05
# 50%    1989.000000  1.054325e+06  3.859886e+06  8.080450e+05
# 75%    2003.000000  1.188700e+06  4.401522e+06  1.081521e+06
# max    2017.000000  1.518396e+06  6.254238e+06  2.571684e+06

# %%
plt.hist(df_hist['GrandCanyon'],facecolor='darkgreen',edgecolor='blue',bins=10,range=(2000000,5000000))
plt.title('Histogram plot of Grand Canyon (2M-5M)')
plt.ylabel('Frequency') 
plt.xlabel('Bins')
plt.show()

# %% [markdown]
# ## 2  Pie Chart: Pie chart shows distribution of data based on proportion of pie occupied.

# %% [markdown]
# #### Importing Libraries and Data

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
df_pie=pd.read_csv("types_movies.csv")
df_pie.head()
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %%
#use value_counts to count categorical values to plot pie chart

# %%
plt.pie(df_pie['Percentage'],labels=df_pie['Sector'])
plt.title("Pie chart of Movies Data Set")
plt.show()

# %% [markdown]
# ### Pie chart components
# * <b>wedges:</b> A list of Patch objects representing each wedge
# * <b>texts:</b> List of Text objects representing the labels
# * <b>autotexts:</b> List of Text objects for the numeric values - this is only availabe if the autopct value for the pie chart is not None

# %%
wedges,texts,autotexts=plt.pie(df_pie['Percentage'],labels=df_pie['Sector'],autopct='%.1f')
plt.title("Pie chart of Movies Data Set")
plt.axis('equal')
print("Wedges: ",wedges)
print("Text: ",texts)
print("Autotext: ",autotexts)
plt.show()
# Out:
# Wedges:  [<matplotlib.patches.Wedge object at 0x0000020F91400B50>, <matplotlib.patches.Wedge object at 0x0000020F91400A60>, <matplotlib.patches.Wedge object at 0x0000020F91401750>, <matplotlib.patches.Wedge object at 0x0000020F91401D80>, <matplotlib.patches.Wedge object at 0x0000020F91402410>]
# Text:  [Text(0.8899186877588753, 0.6465637858537406, 'Sci-Fi'), Text(-0.7778174593052023, 0.7778174593052024, 'Drama'), Text(-0.49938956806635254, -0.9801071672559598, 'Action'), Text(0.4993895336547568, -0.9801071847895437, 'Comedy'), Text(0.9801071789450159, -0.49938954512528877, 'Romance')]
# Autotext:  [Text(0.4854101933230228, 0.35267115592022213, '20.0'), Text(-0.42426406871192845, 0.4242640687119285, '35.0'), Text(-0.2723943098543741, -0.5346039094123416, '25.0'), Text(0.27239429108441277, -0.5346039189761147, '5.0'), Text(0.5346039157881904, -0.27239429734106657, '15.0')]

# %% [markdown]
# #### Pie chart customizations
#  We set the values for the colors and autopct properties. The latter sets the format for the values to be displayed.

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
colors_new=['darkorange','sandybrown','darksalmon','orangered','chocolate']
plt.pie(df_pie['Percentage'],labels=df_pie['Sector'],colors=colors_new)
plt.title("Pie chart of Movies Data Set")
plt.show()

# %% [markdown]
# #### The explode property
# To highlight a particular wedge of the pie chart, we use explode to separate it from the rest of the chart.
#
# The value for "explode" represents the fraction of the radius with which to offset each wedge.

# %%
explode_pie=[0,.1,0,0,.3]
colors_new=['darkorange','sandybrown','darksalmon','orangered','chocolate']
plt.pie(df_pie['Percentage'],labels=df_pie['Sector'],colors=colors_new,explode=explode_pie)
plt.title("Pie chart of Movies Data Set")
plt.show()

# %% [markdown]
# ## 3 Time Series by line plot
# * Time series is a line plot and it is basically connecting data points with a straight line.
# * It is useful in understanding the trend over time.
# * It can explain the correlation between points by the trend.
# * An upward trend means positive correlation and downward trend means a negative correlation.
# * It mostly used in forecasting, monitoring models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_line=pd.read_csv("stocks.csv")

# %%
df_line.sample(6)
# Out:
#          Date        AAPL        ADBE         CVX        GOOG         IBM  \
# 17   2-Jun-08   21.693451   39.389999   72.028023  263.473480   96.824951
# 120  3-Jan-17  121.104935  113.820000  110.759811  823.830017  174.420883
# 100  1-May-15  125.784088   79.089996   95.295212  545.320007  159.311340
# 25   2-Feb-09   11.570964   16.700001   45.243240  169.164169   76.305176
# 99   1-Apr-15  120.328499   76.059998  101.738503  548.770020  159.643234
# 40   3-May-10   33.281258   32.080002   57.709251  243.058060  106.371109
#
#           MDLZ       MSFT        NFLX       ORCL       SBUX
# 17   14.996203  21.957640    3.724286  19.208786   7.096149
# 120  44.430000  64.737526  141.220001  40.230000  55.649239
# 100  40.421711  44.735142   89.151428  42.332653  50.660107
# 25   12.240067  13.118857    5.177143  14.214501   4.125144
# 99   37.292160  46.134602   79.500000  42.459190  48.186340
# 40   16.244190  21.499313   15.878572  20.881126  11.720480

# %%
df_line.describe()
# Out:
#              AAPL        ADBE         CVX        GOOG         IBM        MDLZ  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    58.814823   49.987769   80.874336  404.465671  133.971833   25.667255
# std     36.019209   24.664568   20.391910  190.680656   35.041013   10.296969
# min     10.962033   16.700001   45.243240  146.626633   67.291237   12.135740
# 25%     24.421976   32.369999   60.383438  261.611603  100.155655   16.772554
# 50%     52.477612   39.470001   84.349571  310.300293  146.030731   23.006008
# 75%     90.709122   69.250000   98.638901  554.700012  164.687836   34.103638
# max    125.784088  113.820000  116.584061  823.830017  189.859497   45.207314
#
#              MSFT        NFLX        ORCL        SBUX
# count  121.000000  121.000000  121.000000  121.000000
# mean    30.713787   36.896387   28.654242   25.987711
# std     12.236284   37.471453    8.656507   17.584089
# min     13.118857    2.461429   14.214501    4.025960
# 25%     22.189415    6.277143   20.114820   11.000682
# 50%     25.334867   23.165714   29.318512   21.345242
# 75%     38.565643   59.527142   36.916359   37.392227
# max     64.737526  141.220001   43.502277   61.172874

# %%
df_line.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    121 non-null    object
#  1   AAPL    121 non-null    float64
#  2   ADBE    121 non-null    float64
#  3   CVX     121 non-null    float64
#  4   GOOG    121 non-null    float64
#  5   IBM     121 non-null    float64
#  6   MDLZ    121 non-null    float64
#  7   MSFT    121 non-null    float64
#  8   NFLX    121 non-null    float64
#  9   ORCL    121 non-null    float64
#  10  SBUX    121 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 10.5+ KB

# %%
df_line['Date']=pd.to_datetime(df_line['Date'])
# Out:
# C:\Users\rhukom\AppData\Local\Temp\ipykernel_2600\4071077543.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_line['Date']=pd.to_datetime(df_line['Date'])

# %%
df_line.head()
# Out:
#         Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0 2007-01-03  11.107141  38.869999  50.777351  251.001007  79.242500
# 1 2007-02-01  10.962033  39.250000  48.082939  224.949951  74.503204
# 2 2007-03-01  12.037377  41.700001  51.900383  229.309311  75.561348
# 3 2007-04-02  12.930043  41.560001  54.588032  235.925919  81.934280
# 4 2007-05-01  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %% [markdown]
# ### Compare stocks side by side

# %%
df_line.columns
# Out:
# Index(['Date', 'AAPL', 'ADBE', 'CVX', 'GOOG', 'IBM', 'MDLZ', 'MSFT', 'NFLX',
#        'ORCL', 'SBUX'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(10,6))
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.05,0.65,0.5,0.3])
ax1.set_title('AAPL VS IBM (inset)')
ax1.plot(df_line['Date'],df_line['AAPL'],color='green')
ax2.plot(df_line['Date'],df_line['IBM'],color='blue')
plt.show()

# %% [markdown]
# ## Compare multiple stocks

# %%
fig=plt.figure(figsize=(16,8))
fig.suptitle('Stock price comparison 2007-2017',fontsize=20)
ax1=fig.add_subplot(231) #row=2 , column=3 , position=1
ax1.set_title('MSFT')
ax1.plot(df_line['Date'], df_line['MSFT'],color='green')

ax2=fig.add_subplot(232) #row=2 , column=3 , position=2
ax2.set_title('GOOG')
ax2.plot(df_line['Date'], df_line['GOOG'],color='blue')

ax3=fig.add_subplot(233) #row=2 , column=3 , position=3
ax3.set_title('SBUX')
ax3.plot(df_line['Date'], df_line['SBUX'],color='red')

ax4=fig.add_subplot(234) #row=2 , column=3 , position=4
ax4.set_title('ADBE')
ax4.plot(df_line['Date'], df_line['ADBE'],color='purple')

ax5=fig.add_subplot(235) #row=2 , column=3 , position=5
ax5.set_title('NFLX')
ax5.plot(df_line['Date'], df_line['NFLX'],color='black')

ax6=fig.add_subplot(236) #row=2 , column=3 , position=6
ax6.set_title('ORCL')
ax6.plot(df_line['Date'], df_line['ORCL'],color='teal')

plt.show()

# %% [markdown]
# # https://matplotlib.org/stable/api/colors_api.html

# %% [markdown]
# ## 4 Boxplot
# Boxplot gives a nice summary of the data. It helps in understanding our distribution better.
# ![image.png](attachment:image.png)
# * The end of the box shows the upper quartile(75%)and the start of the box represents the lower quartile(25%).
# * Upper Quartile is also called 3rd quartile and similarly, Lower Quartile is also called as 1st quartile.
# * The region between lower quartile and the upper quartile is called as Inter Quartile Range(IQR) and it is used to approximate the 50% spread in the middle data(75–25=50%).

# %%
import matplotlib.pyplot as plt
import pandas as pd
df_exam=pd.read_csv('exams.csv')

# %%
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
exam_score=df_exam[['math score', 'reading score', 'writing score']]

# %% [markdown]
# ###  Box plots

# %%
plt.boxplot(exam_score,patch_artist=True,notch=True)
plt.xticks([1,2,3],['Math','Reading','Writing'])
plt.title('Boxplot of Scores')
plt.show()

# %%
exam_score.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %% [markdown]
# ### Violin Plots
# Violin plot is a better chart than boxplot as it gives a much broader understanding of the distribution. It resembles a violin and dense areas point the more distribution of data otherwise hidden by box plots

# %%
plt.violinplot(exam_score,showmedians=True)
plt.xticks([1,2,3],['Math','Reading','Writing'])
plt.title('Boxplot of Scores')
plt.show()

# %% [markdown]
# ## TwinAxis
# * TwinAxis helps in visualizing plotting 2 plots w.r.t to the y-axis and same x-axis.
# * It should when we require 2 plots or grouped data in the same direction.

# %%
import matplotlib.pyplot as plt
import pandas as pd
df_twin=pd.read_csv("austin_weather.csv")

# %%
df_twin.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
df_twin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
#  13  VisibilityHighMiles         1319 non-null   object
#  14  VisibilityAvgMiles          1319 non-null   object
#  15  VisibilityLowMiles          1319 non-null   object
#  16  WindHighMPH                 1319 non-null   object
#  17  WindAvgMPH                  1319 non-null   object
#  18  WindGustMPH                 1319 non-null   object
#  19  PrecipitationSumInches      1319 non-null   object
#  20  Events                      1319 non-null   object
# dtypes: int64(3), object(18)
# memory usage: 216.5+ KB

# %% [markdown]
# #### Extracting Date,Avg Temperature and Avg Wind Speed columns

# %%
df_twin.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
austin_weather=df_twin[['Date','TempAvgF','WindAvgMPH']].head(30)
austin_weather.head()
# Out:
#          Date  TempAvgF WindAvgMPH
# 0  2013-12-21        60          4
# 1  2013-12-22        48          6
# 2  2013-12-23        45          3
# 3  2013-12-24        46          4
# 4  2013-12-25        50          2

# %% [markdown]
# ### Plotting two lines with 2 separate Y axes with the same X axis
# First create one axis and then use the twinx() function to create another axis sharing the same X axis
# ![image.png](attachment:image.png)

# %%
fig,ax1=plt.subplots()
fig=plt.figure(figsize=(12,6))

#set x label with the date variable
ax1.set_xlabel('Date')
#disabling ticks and labels from bottom
ax1.tick_params(axis='x',bottom=False, labelbottom=False)

ax1.set_ylabel('Temp (F)',color='red',size='x-large')
ax1.tick_params(axis='y',labelcolor='red',labelsize='large')

ax1.plot(austin_weather['Date'],austin_weather['TempAvgF'],color='red')

ax2=ax1.twinx()
ax2.set_ylabel('Avg windspeed (MPH)',color='blue',size='x-large')
ax2.tick_params(axis='y',labelcolor='blue',labelsize='large')

ax2.plot(austin_weather['Date'],austin_weather['WindAvgMPH'],color='blue')

plt.show()

# %% [markdown]
# ### Twin axis for the same data
# If the same data can be expressed in different units, we can configure our axis to display both units on two axes.
# ![image.png](attachment:image.png)

# %%
def f2c(f):
    return (f-32)*5/9

# %%
fig,ax1=plt.subplots()
fig=plt.figure(figsize=(12,6))

#set x label with the date variable
ax1.set_xlabel('Date')
#disabling ticks and labels from bottom
ax1.tick_params(axis='x',bottom=False, labelbottom=False)

ax1.set_ylabel('Temp (F)',color='red',size='x-large')
ax1.tick_params(axis='y',labelcolor='red',labelsize='large')

ax1.plot(austin_weather['Date'],austin_weather['TempAvgF'],color='red')

ax2=ax1.twinx()
#getting y limit from temp(F)

ymin,ymax=ax1.get_ylim()
ax2.set_ylim(f2c(ymin),f2c(ymax))
ax2.set_ylabel('Temp (C)',color='green',size='large')
ax2.tick_params(axis='y', labelcolor='green',labelsize='large')

plt.show()

# %% [markdown]
# ## 6 Stack Plot
# * Stack plot visualizes data in stacks and shows the distribution of data over time.
# * It is used for checking multiple variable area plots in a single plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_park=pd.read_csv('national_parks.csv')
df_park.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
x=df_park['Year']
y=np.vstack([df_park['Badlands'],df_park['GrandCanyon'],df_park['BryceCanyon']])

# %%
label_park=['Badlands','GrandCanyon', 'BryceCanyon']
plt.stackplot(x,y,labels=label_park)
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## 7 Bar Plot
# * Bar Plot shows the distribution of data over several groups.
# * It is commonly confused with a histogram which only takes numerical data for plotting.
# * It helps in comparing multiple numeric values.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_bar=pd.read_csv('countries.csv')

# %%
df_bar.sample(5)
# Out:
#                        country continent  year  lifeExpectancy  population  \
# 317                    Comoros    Africa  1977          50.939      304739
# 237                   Cameroon    Africa  1997          52.199    14195809
# 1199                  Paraguay  Americas  2007          71.752     6667147
# 256   Central African Republic    Africa  1972          43.457     1927260
# 1030                   Morocco    Africa  2002          69.615    31167783
#
#       gdpPerCapita
# 317    1172.603047
# 237    1694.337469
# 1199   4172.838464
# 256    1070.013275
# 1030   3258.495584

# %%
df_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         1704 non-null   object
#  1   continent       1704 non-null   object
#  2   year            1704 non-null   int64
#  3   lifeExpectancy  1704 non-null   float64
#  4   population      1704 non-null   int64
#  5   gdpPerCapita    1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
# plot year (2007) vs population (top 10 populated country)
year_2007=df_bar[df_bar['year']==2007]

# %%
year_2007
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 11           Afghanistan      Asia  2007          43.828    31889923
# 23               Albania    Europe  2007          76.423     3600523
# 35               Algeria    Africa  2007          72.301    33333216
# 47                Angola    Africa  2007          42.731    12420476
# 59             Argentina  Americas  2007          75.320    40301927
# ...                  ...       ...   ...             ...         ...
# 1655             Vietnam      Asia  2007          74.249    85262356
# 1667  West Bank and Gaza      Asia  2007          73.422     4018332
# 1679         Yemen, Rep.      Asia  2007          62.698    22211743
# 1691              Zambia    Africa  2007          42.384    11746035
# 1703            Zimbabwe    Africa  2007          43.487    12311143
#
#       gdpPerCapita
# 11      974.580338
# 23     5937.029526
# 35     6223.367465
# 47     4797.231267
# 59    12779.379640
# ...            ...
# 1655   2441.576404
# 1667   3025.349798
# 1679   2280.769906
# 1691   1271.211593
# 1703    469.709298
#
# [142 rows x 6 columns]

# %%
top_10_p=year_2007.sort_values('population',ascending=False).head(10)

# %%
plt.figure(figsize=(12,6))
x=range(10)
plt.bar(x,top_10_p['population'])
plt.xticks(x,top_10_p['country'])
plt.xlabel('countries')
plt.ylabel('Population in billions')
plt.title('Top 10 populated country')
plt.show()

# %% [markdown]
# ## 8 Scatter Plot
# * Scatter plot helps in visualizing 2 numeric variables.
# * It helps in identifying the relationship of the data with each variable i.e correlation or trend patterns.
# * It also helps in detecting outliers in the plot.
# * It is used in Machine learning concepts like regression, where x and y are continuous variables. It is also used in clustering scatters or outlier detection.

# %%
year_2007.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExpectancy', 'population',
#        'gdpPerCapita'],
#       dtype='object')

# %%
plt.scatter(year_2007['gdpPerCapita'],year_2007['lifeExpectancy'])
plt.title("GDP per Capita vs. Life Expectancy in the year 2007")
plt.xlabel('GDP per Capita')
plt.ylabel('Life Expectancy')
plt.show()

# %%
#correlation
year_2007['gdpPerCapita'].corr(year_2007['lifeExpectancy'])
# Out:
# 0.6786623986777587

# %%
#population vs life epectancy
plt.scatter(year_2007['population'],year_2007['lifeExpectancy'])
plt.title("Population vs. Life Expectancy in the year 2007")
plt.xlabel('Population')
plt.ylabel('Life Expectancy')
plt.show()

# %%
#correlation
year_2007['population'].corr(year_2007['lifeExpectancy'])
# Out:
# 0.04755311503282725
